# %%
class Gerador:
  def __init__(self,barra,p_ativa, q_reativo,min_ativa, max_ativa):
    self.barra = barra
    self.ativo = p_ativa
    self.reativo = q_reativo
    self.min_ativo = min_ativa
    self.max_ativo = max_ativa


class Linha:
  def __init__(self,de,para,impedancia,resistencia,reatancia,susceptancia,cap_normal,cap_emergencia):
    self.de = de
    self.para = para
    self.impedancia = impedancia
    self.resistencia = resistencia
    self.reatancia = reatancia
    self.susceptancia = susceptancia
    self.cap_normal = cap_normal
    self.cap_emergencia = cap_emergencia

# %%
#[barra_de, barra_para, impedancia (R + Xj), resistencia, reatancia, susceptancia, cap_normal, cap_emergencia]

dados_linhas = [
    [1, 2, 1.94 + 5.92j, 1.94, 5.92, 5.28, 100.0, 200.0],
    [1, 2, 1.94 + 5.92j, 1.94, 5.92, 5.28, 100.0, 200.0],
    [1, 5, 5.40 + 22.30j, 5.40, 22.30, 4.92, 100.0, 200.0],
    [2, 3, 4.70 + 19.80j, 4.70, 19.80, 4.38, 100.0, 200.0],
    [2, 4, 5.81 + 17.63j, 5.81, 17.63, 3.75, 100.0, 200.0],
    [2, 5, 5.69 + 17.39j, 5.69, 17.39, 3.40, 100.0, 200.0],
    [3, 4, 6.70 + 17.10j, 6.70, 17.10, 3.46, 100.0, 200.0],
    [6, 11, 9.50 + 19.89j, 9.50, 19.89, 0.0, 50.0, 150.0],
    [6, 12, 12.29 + 25.58j, 12.29, 25.58, 0.0, 50.0, 150.0],
    [6, 13, 6.61 + 13.03j, 6.61, 13.03, 0.0, 50.0, 150.0],
    [9, 10, 3.18 + 8.45j, 3.18, 8.45, 0.0, 50.0, 150.0],
    [9, 14, 12.71 + 27.04j, 12.71, 27.04, 0.0, 50.0, 150.0],
    [10, 11, 8.20 + 19.21j, 8.20, 19.21, 0.0, 50.0, 150.0],
    [12, 13, 22.09 + 19.99j, 22.09, 19.99, 0.0, 50.0, 150.0],
    [13, 14, 17.09 + 34.80j, 17.09, 34.80, 0.0, 50.0, 150.0],
    [15, 5, 1.34 + 5.00j, 1.34, 5.00, 1.28, 100.0, 200.0]
]

# %%
#[barra, geracao_ativa, geracao_reativa, geracao_ativa_minima, geracao_ativa_maxima]

dados_geradores = [
    [1, 183.6, 7.352, 40.0, 250.0],
    [2, 27.43, 3.907, 20.0, 60.0],
    [3, 0.0, 27.88, 0.0, 0.0],
    [6, 21.69, -6.0, 5.0, 40.0],
    [8, 0.0, -20.0, 0.0, 0.0],
    [12, 0.0, -12.2, 0.0, 0.0],
    [14, 47.69, 10.0, 5.0, 50.0]
]

# %%
carga_ativa =[
    0,21.7,94.2,47.8,-100,130,0,0,29.5,9,3.5,0,13.5,14.9,0
]
